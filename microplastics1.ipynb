# %%
# !pip install ultralytics
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
from ultralytics import YOLO

# Load model (YOLOv5n = nano/tiny version, fastest, lowest resource use)
model = YOLO('yolov5nu.pt')

# Train: adjust epochs, batch, img size as needed
model.train(
    data=r'C:/Users/Ajinkya/PBL/data.yaml',
    epochs=50,
    imgsz=640,
    batch=16,
    device='cuda'  # uses GPU
)
# Out:
# Ultralytics 8.3.221  Python-3.12.7 torch-2.5.1 CUDA:0 (NVIDIA GeForce RTX 4050 Laptop GPU, 6140MiB)
# ...
